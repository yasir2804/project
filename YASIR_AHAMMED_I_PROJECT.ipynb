# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/default of credit card clients.csv")

# %%
df=pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
#  13  BILL_AMT2                   30000 non-null  int64
#  14  BILL_AMT3                   30000 non-null  int64
#  15  BILL_AMT4                   30000 non-null  int64
#  16  BILL_AMT5                   30000 non-null  int64
#  17  BILL_AMT6                   30000 non-null  int64
#  18  PAY_AMT1                    30000 non-null  int64
#  19  PAY_AMT2                    30000 non-null  int64
#  20  PAY_AMT3                    30000 non-null  int64
#  21  PAY_AMT4                    30000 non-null  int64
#  22  PAY_AMT5                    30000 non-null  int64
#  23  PAY_AMT6                    30000 non-null  int64
#  24  default payment next month  30000 non-null  int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# std        9.217904      1.123802      1.197186      1.196868      1.169139
# min       21.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       28.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%       34.000000      0.000000      0.000000      0.000000      0.000000
# 75%       41.000000      0.000000      0.000000      0.000000      0.000000
# max       79.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count  ...   30000.000000   30000.000000   30000.000000   30000.000000
# mean   ...   43262.948967   40311.400967   38871.760400    5663.580500
# std    ...   64332.856134   60797.155770   59554.107537   16563.280354
# min    ... -170000.000000  -81334.000000 -339603.000000       0.000000
# 25%    ...    2326.750000    1763.000000    1256.000000    1000.000000
# 50%    ...   19052.000000   18104.500000   17071.000000    2100.000000
# 75%    ...   54506.000000   50190.500000   49198.250000    5006.000000
# max    ...  891586.000000  927171.000000  961664.000000  873552.000000
#
#            PAY_AMT2      PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  3.000000e+04   30000.00000   30000.000000   30000.000000
# mean   5.921163e+03    5225.68150    4826.076867    4799.387633
# std    2.304087e+04   17606.96147   15666.159744   15278.305679
# min    0.000000e+00       0.00000       0.000000       0.000000
# 25%    8.330000e+02     390.00000     296.000000     252.500000
# 50%    2.009000e+03    1800.00000    1500.000000    1500.000000
# 75%    5.000000e+03    4505.00000    4013.250000    4031.500000
# max    1.684259e+06  896040.00000  621000.000000  426529.000000
#
#             PAY_AMT6  default payment next month
# count   30000.000000                30000.000000
# mean     5215.502567                    0.221200
# std     17777.465775                    0.415062
# min         0.000000                    0.000000
# 25%       117.750000                    0.000000
# 50%      1500.000000                    0.000000
# 75%      4000.000000                    0.000000
# max    528666.000000                    1.000000
#
# [8 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29995    False
# 29996    False
# 29997    False
# 29998    False
# 29999    False
# Length: 30000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0         -1  ...          0          0          0         0       689
# 1          0  ...       3272       3455       3261         0      1000
# 2          0  ...      14331      14948      15549      1518      1500
# 3          0  ...      28314      28959      29547      2000      2019
# 4          0  ...      20940      19146      19131      2000     36681
# ...      ...  ...        ...        ...        ...       ...       ...
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0             0         0         0         0                           1
# 1          1000      1000         0      2000                           1
# 2          1000      1000      1000      5000                           0
# 3          1200      1100      1069      1000                           0
# 4         10000      9000       689       679                           0
# ...         ...       ...       ...       ...                         ...
# 29995      5003      3047      5000      1000                           0
# 29996      8998       129         0         0                           0
# 29997     22000      4200      2000      3100                           1
# 29998      1178      1926     52964      1804                           1
# 29999      1430      1000      1000      1000                           1
#
# [30000 rows x 25 columns]

# %%
sns.boxplot(x=df['LIMIT_BAL'],y='PAY_AMT1',data=df)
plt.title("Outlier detection using boxplot")
plt.show()

# %%
def handling_outliers(df):
    numerical_features = df.select_dtypes(include=['number']).columns
    numerical_features = numerical_features.drop('Product', errors='ignore')
    for col in numerical_features:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        Lower_bound = Q1 - (1.5 * IQR)
        Upper_bound = Q3 + (1.5 * IQR)
        df = df[(df[col] >= Lower_bound) & (df[col] <= Upper_bound)]
    return df
df = handling_outliers(df.copy())

# %%
df.shape
# Out:
# (7115, 25)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
y=df['PAY_AMT1']

# %%
x=df.drop('LIMIT_BAL',axis=1)

# %%
x.columns
# Out:
# Index(['ID', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3',
#        'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3',
#        'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2',
#        'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
le=LabelEncoder()

# %%
y=le.fit_transform(y)

# %%
y
# Out:
# array([1178, 1437,  146, ...,    0,    0, 1178])

# %%
sns.boxplot(x='LIMIT_BAL', y='PAY_AMT1', data=df)
plt.title("Boxplot")
plt.show()

# %%
sns.scatterplot(x='LIMIT_BAL', y='PAY_AMT1', data=df, color='r')
plt.title("Scatterplot")
plt.show()

# %%
AGE_mapping = {'18-24': '19', '25-29': '25', '30-34': '30', '35-39': '35', '40-44': '40', '45-49': '45', '50-54': '50', '55-59': '55', '60-64': '60', '65-69': '65', '70-74': '70', '75-79': '75', '80 or older': '80'}

df['AGE'] = df['AGE'].map(AGE_mapping)
df['AGE'] = pd.to_numeric(df['AGE'])
df['LIMIT_BAL'] = df['LIMIT_BAL'].map({'Yes': 1, 'No': 0})
correlation_matrix = df[['AGE', 'LIMIT_BAL']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='viridis')
plt.title("Heatmap")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /usr/local/lib/python3.11/dist-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)

# %%
df['BILL_AMT1']=df['BILL_AMT1'].replace({'\$':'',',':''},regex=True).astype(float)
sns.kdeplot(df['BILL_AMT1'],fill=True,color='b')
plt.title("KDE plot")
plt.show()

# %%
df['PAY_6'].value_counts().plot(kind='pie',autopct='%1.1f%%',colors=['lightblue','orange'])
plt.title("Piechart")
plt.show()

# %%
numeric_df = df.select_dtypes(include=np.number)
numeric_df.skew()
# Out:
# ID                                 NaN
# LIMIT_BAL                          NaN
# SEX                          -0.452267
# EDUCATION                          NaN
# MARRIAGE                     -0.060801
# AGE                                NaN
# PAY_0                        -0.593157
# PAY_2                        -0.742252
# PAY_3                        -0.615624
# PAY_4                        -0.536164
# PAY_5                        -0.476288
# PAY_6                        -0.376314
# BILL_AMT1                     1.462896
# BILL_AMT2                     1.327199
# BILL_AMT3                     1.247149
# BILL_AMT4                     1.159328
# BILL_AMT5                     1.126315
# BILL_AMT6                     1.187405
# PAY_AMT1                           NaN
# PAY_AMT2                      0.989181
# PAY_AMT3                      1.082095
# PAY_AMT4                      1.164108
# PAY_AMT5                      1.087198
# PAY_AMT6                           NaN
# default payment next month    0.000000
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
import numpy as np
numeric_df = df.select_dtypes(include=['number'])
skewed_cols = numeric_df.columns[numeric_df.skew().abs() > 1]
for col in skewed_cols:
    if col in df.columns:
        df[col] = np.log1p(df[col]) if (df[col] > 0).all() else PowerTransformer(method='yeo-johnson').fit_transform(df[[col]])

print("Skewness After Transformation:\n", df[skewed_cols].skew())
# Out:
# Skewness After Transformation:
#  BILL_AMT1   -0.652387
# BILL_AMT2   -0.894188
# BILL_AMT3   -1.091941
# BILL_AMT4   -1.179475
# BILL_AMT5   -1.396979
# BILL_AMT6   -1.695015
# PAY_AMT3    -0.531950
# PAY_AMT4    -0.439478
# PAY_AMT5    -0.407169
# dtype: float64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import SelectKBest,f_classif
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
# !pip install scikit-learn
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

x = df.drop(columns='BILL_AMT1', axis=1)
y = df['BILL_AMT1']
categorical_features = x.select_dtypes(include=['object']).columns
numerical_features = x.select_dtypes(exclude=['object']).columns
numerical_pipeline = Pipeline([
      ('imputer', SimpleImputer(strategy='mean')),
      ('num', 'passthrough')
])
categorical_pipeline = Pipeline([
      ('imputer', SimpleImputer(strategy='most_frequent')),
      ('cat', OneHotEncoder(sparse_output=False, handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(
      transformers=[
          ('num_pipe', numerical_pipeline, numerical_features),
          ('cat_pipe', categorical_pipeline, categorical_features)
     ]
)
x_encoded = preprocessor.fit_transform(x)
feature_names = preprocessor.get_feature_names_out(input_features=x.columns)
x_encoded_df = pd.DataFrame(x_encoded, columns=feature_names)


selecter = SelectKBest(score_func=f_classif, k=4)
x_new = selecter.fit_transform(x_encoded_df, y)
selected_features = x_encoded_df.columns[selecter.get_support()]
feature_score = pd.DataFrame({'features': x_encoded_df.columns, 'score': selecter.scores_}).sort_values(by='score', ascending=False)

print("Selected features")
print(selected_features)
print("\nFeature scores")
print(feature_score)
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# /usr/local/lib/python3.11/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['ID' 'LIMIT_BAL' 'EDUCATION' 'AGE' 'PAY_AMT1' 'PAY_AMT6']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# Selected features
# Index(['num_pipe__BILL_AMT2', 'num_pipe__BILL_AMT3', 'num_pipe__BILL_AMT4',
#        'num_pipe__BILL_AMT5'],
#       dtype='object')
#
# Feature scores
#                                 features      score
# 8                    num_pipe__BILL_AMT2  74.427253
# 9                    num_pipe__BILL_AMT3  35.883740
# 10                   num_pipe__BILL_AMT4  22.210185
# 11                   num_pipe__BILL_AMT5  11.165924
# 12                   num_pipe__BILL_AMT6   5.661122
# 3                        num_pipe__PAY_2   5.347439
# 4                        num_pipe__PAY_3   3.776415
# 5                        num_pipe__PAY_4   3.175531
# 7                        num_pipe__PAY_6   2.838209
# 6                        num_pipe__PAY_5   2.756821
# 13                    num_pipe__PAY_AMT2   2.057336
# 15                    num_pipe__PAY_AMT4   1.592784
# 14                    num_pipe__PAY_AMT3   1.589289
# 16                    num_pipe__PAY_AMT5   1.551273
# 0                          num_pipe__SEX   1.130070
# 1                     num_pipe__MARRIAGE   0.973807
# 2                        num_pipe__PAY_0   0.381385
# 17  num_pipe__default payment next month        NaN
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:111: UserWarning: Features [17] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:112: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
#Split data into training and testing
x_train,x_test,y_train,y_test=train_test_split(x_encoded_df,y,test_size=0.2,random_state=42)

# %%
Ss=StandardScaler()
x_test_scaled=Ss.fit_transform(x_test)
x_train_scaled=Ss.fit_transform(x_train)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,confusion_matrix,classification_report

# %%
classifiers={
    'Logistic Regression':LogisticRegression(),
    'Decision Tree':DecisionTreeClassifier(),
    'SVM':SVC(),
    'RFC':RandomForestClassifier()
}

# %%
y_train_discrete = (y_train > 0).astype(int)
y_test_discrete = (y_test > 0).astype(int)
for name,clf in classifiers.items():
    clf.fit(x_train_scaled,y_train_discrete) # Use the discrete target for training
    y_pred=clf.predict(x_test_scaled)
    print(f"\n{name}Results:")
    print("Accuracy:",accuracy_score(y_test_discrete,y_pred)) # Use the discrete target for evaluation
    print("\nConfusion Matrix:")
    print(confusion_matrix(y_test_discrete,y_pred))
    print("\nClassification Report:")
# Out:
# Logistic RegressionResults:
# Accuracy: 0.9388615600843289
#
# Confusion Matrix:
# [[740  56]
#  [ 31 596]]
#
# Classification Report:
#
# Decision TreeResults:
# Accuracy: 0.9304286718200984
#
# Confusion Matrix:
# [[751  45]
#  [ 54 573]]
#
# Classification Report:
#
# SVMResults:
# Accuracy: 0.9388615600843289
#
# Confusion Matrix:
# [[750  46]
#  [ 41 586]]
#
# Classification Report:
#
# RFCResults:
# Accuracy: 0.9529163738580464
#
# Confusion Matrix:
# [[783  13]
#  [ 54 573]]
#
# Classification Report:
